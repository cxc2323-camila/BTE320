# %% [markdown]
# <a href="https://colab.research.google.com/github/cxc2323-camila/BTE320/blob/main/23_01_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales value ($):"))
cogs = 0.4 * sales
gross_profit= sales - cogs

print(f"Sales: {sales}$")
print(f"Cost of Goods Sold: {cogs}$")
print(f"Gross Profit: {gross_profit} $")
# Out:
# Enter sales value ($):12000
# Sales: 12000.0$
# Cost of Goods Sold: 4800.0$
# Gross Profit: 7200.0 $
